# %% [markdown]
# ### Load the Data

# %%
#import neccessary packages
import numpy as np
import pandas as pd

# %%
#data
data = pd.read_csv('hp_data.csv')
data
# Out:
#                      place                 built  sqft    sale  yearsOld  \
# 0               BTM Layout  Super built-up  Area  1450  Resale         5
# 1                Yelahanka  Super built-up  Area  2190  Resale         5
# 2               Whitefield  Super built-up  Area  1019  Resale         1
# 3               Ambalipura  Super built-up  Area  1857  Resale        15
# 4                Yelahanka  Super built-up  Area  2190  Resale         5
# ...                    ...                   ...   ...     ...       ...
# 3495            Whitefield  Super built-up  Area  1019  Resale         1
# 3496            BTM Layout  Super built-up  Area  1450  Resale         5
# 3497        Yelachenahalli  Super built-up  Area  1330  Resale        10
# 3498  Abbaiah Reddy Layout        Built-up  Area  1200  Resale        10
# 3499            Whitefield  Super built-up  Area  1019  Resale         1
#
#       floor  totalFloor  bhk     price
# 0         1           4    1   6300000
# ...

# %% [markdown]
# ### Exploratary Data Analysis :
# - Imp. pipeline of ML and DS project where we analysis each and every feature by statistically and graphically.
# - Statistical Analysis
#     * Basis Chacks
# - Graphical Analysis
#     * Univariate Analysis, Bivariate Analysis, Multivariate Analysis

# %%
# 1. Understand data
data.head()#top 5 row
# Out:
#         place                 built  sqft    sale  yearsOld  floor  \
# 0  BTM Layout  Super built-up  Area  1450  Resale         5      1
# 1   Yelahanka  Super built-up  Area  2190  Resale         5      3
# 2  Whitefield  Super built-up  Area  1019  Resale         1      2
# 3  Ambalipura  Super built-up  Area  1857  Resale        15      4
# 4   Yelahanka  Super built-up  Area  2190  Resale         5      3
#
#    totalFloor  bhk     price
# 0           4    1   6300000
# 1           5    3  11500000
# 2           5    2   3800000
# 3           5    4  10500000
# 4           5    3  11500000

# %%
data.tail()#bottom 5 row
# Out:
#                      place                 built  sqft    sale  yearsOld  \
# 3495            Whitefield  Super built-up  Area  1019  Resale         1
# 3496            BTM Layout  Super built-up  Area  1450  Resale         5
# 3497        Yelachenahalli  Super built-up  Area  1330  Resale        10
# 3498  Abbaiah Reddy Layout        Built-up  Area  1200  Resale        10
# 3499            Whitefield  Super built-up  Area  1019  Resale         1
#
#       floor  totalFloor  bhk    price
# 3495      2           5    2  3800000
# 3496      1           4    1  6300000
# 3497      1           4    1  7350000
# 3498      1           4    1  4800000
# 3499      2           5    2  3800000

# %%
data.shape#shape of data
# Out:
# (3500, 9)

# %%
data.columns#columns od data
# Out:
# Index(['place', 'built', 'sqft', 'sale', 'yearsOld', 'floor', 'totalFloor',
#        'bhk', 'price'],
#       dtype='object')

# %%
data.info()#information related to data type of each columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   place       3500 non-null   object
#  1   built       3500 non-null   object
#  2   sqft        3500 non-null   int64
#  3   sale        3500 non-null   object
#  4   yearsOld    3500 non-null   int64
#  5   floor       3500 non-null   int64
#  6   totalFloor  3500 non-null   int64
#  7   bhk         3500 non-null   int64
#  8   price       3500 non-null   int64
# dtypes: int64(6), object(3)
# memory usage: 246.2+ KB

# %%
data.describe()#all math values of each columns
# Out:
#               sqft     yearsOld        floor   totalFloor          bhk  \
# count  3500.000000  3500.000000  3500.000000  3500.000000  3500.000000
# mean   1538.163143     7.602000     4.197714     6.371429     4.197714
# std     416.264178     3.803196     4.782410     4.461808     4.782410
# min    1019.000000     1.000000     1.000000     4.000000     1.000000
# 25%    1200.000000     5.000000     1.000000     4.000000     1.000000
# 50%    1543.000000     5.000000     3.000000     4.000000     3.000000
# 75%    1784.000000    10.000000     4.000000     5.000000     4.000000
# max    4856.000000    15.000000    18.000000    29.000000    18.000000
#
#               price
# count  3.500000e+03
# mean   8.067807e+06
# std    4.984973e+06
# min    3.800000e+06
# 25%    4.800000e+06
# 50%    6.600000e+06
# 75%    1.050000e+07
# max    4.750000e+07

# %%
data.nunique()#unique values in columns
# Out:
# place         15
# built          2
# sqft          15
# sale           1
# yearsOld       4
# floor          8
# totalFloor     6
# bhk            8
# price         15
# dtype: int64

# %%
data["place"].unique()#unique value of individual columns
# Out:
# array(['BTM Layout', 'Yelahanka', 'Whitefield', 'Ambalipura',
#        'Devarabeesana Halli', 'Yelachenahalli', 'KR Puram',
#        'Electronics City Phase 1', 'Abbaiah Reddy Layout',
#        'Subramanyapura', 'Rajaji Nagar', 'Sarakki Nagar', 'Gunjur',
#        'Malleshwaram', 'Frazer Town'], dtype=object)

# %%
data["place"].value_counts()#value counts of individual columns
# Out:
# Devarabeesana Halli         368
# KR Puram                    358
# BTM Layout                  356
# Abbaiah Reddy Layout        352
# Electronics City Phase 1    351
# Ambalipura                  340
# Yelahanka                   337
# Whitefield                  327
# Subramanyapura              323
# Yelachenahalli              321
# Sarakki Nagar                18
# Malleshwaram                 17
# Gunjur                       12
# Frazer Town                  11
# Rajaji Nagar                  9
# Name: place, dtype: int64

# %%
data.isnull().sum()#missing or NaN value in data
# Out:
# place         0
# built         0
# sqft          0
# sale          0
# yearsOld      0
# floor         0
# totalFloor    0
# bhk           0
# price         0
# dtype: int64

# %%
# 2 relationship analysis
corr = data.corr()
corr
# Out:
#                 sqft  yearsOld     floor  totalFloor       bhk     price
# sqft        1.000000  0.229461  0.356053    0.358946  0.356053  0.778364
# yearsOld    0.229461  1.000000 -0.116427   -0.142562 -0.116427  0.215712
# floor       0.356053 -0.116427  1.000000    0.958100  1.000000  0.263472
# totalFloor  0.358946 -0.142562  0.958100    1.000000  0.958100  0.402256
# bhk         0.356053 -0.116427  1.000000    0.958100  1.000000  0.263472
# price       0.778364  0.215712  0.263472    0.402256  0.263472  1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(co

# %%
sns.heatmap(corr,xticklabels = corr.columns, yticklabels = corr.columns, annot=True)

# %%
sns.pairplot(corr)

# %%
sns.relplot( x = 'price', y = 'sqft', hue = 'bhk', data = data)

# %% [markdown]
# ### Univariate, Bivariate, Multivariate Analaysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('iris.csv')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  target
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2
#
# [150 rows x 5 columns]

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  target
# 0           5.1          3.5           1.4          0.2       0
# 1           4.9          3.0           1.4          0.2       0
# 2           4.7          3.2           1.3          0.2       0
# 3           4.6          3.1           1.5          0.2       0
# 4           5.0          3.6           1.4          0.2       0

# %%
data.shape
# Out:
# (150, 5)

# %% [markdown]
# ##### Unvariate Analysis :
# - We picked up only one feature, based on this feature we will try to determine what the output is.

# %%
d0 = data.loc[data["target"]==0]
d0
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  target
# 0            5.1          3.5           1.4          0.2       0
# 1            4.9          3.0           1.4          0.2       0
# 2            4.7          3.2           1.3          0.2       0
# 3            4.6          3.1           1.5          0.2       0
# 4            5.0          3.6           1.4          0.2       0
# 5            5.4          3.9           1.7          0.4       0
# 6            4.6          3.4           1.4          0.3       0
# 7            5.0          3.4           1.5          0.2       0
# 8            4.4          2.9           1.4          0.2       0
# 9            4.9          3.1           1.5          0.1       0
# 10           5.4          3.7           1.5          0.2       0
# 11           4.8          3.4           1.6          0.2       0
# 12           4.8          3.0           1.4          0.1       0
# ...

# %%
d1 = data.loc[data["target"]==1]
d1
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  target
# 50           7.0          3.2           4.7          1.4       1
# 51           6.4          3.2           4.5          1.5       1
# 52           6.9          3.1           4.9          1.5       1
# 53           5.5          2.3           4.0          1.3       1
# 54           6.5          2.8           4.6          1.5       1
# 55           5.7          2.8           4.5          1.3       1
# 56           6.3          3.3           4.7          1.6       1
# 57           4.9          2.4           3.3          1.0       1
# 58           6.6          2.9           4.6          1.3       1
# 59           5.2          2.7           3.9          1.4       1
# 60           5.0          2.0           3.5          1.0       1
# 61           5.9          3.0           4.2          1.5       1
# 62           6.0          2.2           4.0          1.0       1
# ...

# %%
d2 = data.loc[data["target"]==2]
d2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  target
# 100           6.3          3.3           6.0          2.5       2
# 101           5.8          2.7           5.1          1.9       2
# 102           7.1          3.0           5.9          2.1       2
# 103           6.3          2.9           5.6          1.8       2
# 104           6.5          3.0           5.8          2.2       2
# 105           7.6          3.0           6.6          2.1       2
# 106           4.9          2.5           4.5          1.7       2
# 107           7.3          2.9           6.3          1.8       2
# 108           6.7          2.5           5.8          1.8       2
# 109           7.2          3.6           6.1          2.5       2
# 110           6.5          3.2           5.1          2.0       2
# 111           6.4          2.7           5.3          1.9       2
# 112           6.8          3.0           5.5          2.1       2
# ...

# %%
plt.plot(d0['sepal_length'],np.zeros_like(d0['sepal_length']),"o")
plt.plot(d1['sepal_length'],np.zeros_like(d1['sepal_length']),"o")
plt.plot(d2['sepal_length'],np.zeros_like(d2['sepal_length']),"o")
plt.xlabel("petal length")
plt.show()

# %% [markdown]
# ##### Bivariate Analysis :
# - We picked up two feature, based on these feature we will try to determine what the output is.

# %%
sns.FacetGrid(data,hue="target", size=5).map(plt.scatter,"petal_length","sepal_width").add_legend();
plt.show()
# Out:
# F:\Anaconda\anaconda setup\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ##### Multivariate Analysis :
# - We picked up more than two feature, based on these feature we will try to determine what the output is.

# %%
sns.pairplot(data,hue="target",size=3)
# Out:
# F:\Anaconda\anaconda setup\lib\site-packages\seaborn\axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
