# %%
import pandas as pd

# %%
mov_data = pd.read_csv("tmdb_5000_movies.csv")

# %%
mov_data
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
type(mov_data)
# Out:
# pandas.core.frame.DataFrame

# %%
mov_data.shape
# Out:
# (4803, 20)

# %%
mov_data.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
mov_data.index
# Out:
# RangeIndex(start=0, stop=4803, step=1)

# %%
mov_data.head()#gives starting 5  rows
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
mov_data.tail()#gives ending 5  rows
# Out:
#       budget                                             genres  \
# 4798  220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# ...

# %%
mov_data.head(10)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
mov_data.tail(10)
# Out:
#       budget                                             genres  \
# 4793       0                      [{"id": 18, "name": "Drama"}]
# 4794       0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 4795       0                      [{"id": 18, "name": "Drama"}]
# 4796    7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4797       0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 4798  220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 4793                                                NaN  182291
# 4794                                                NaN  286939
# 4795                                                NaN  124606
# ...

# %%
mov_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
mov_data.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %% [markdown]
# ## selecting columns

# %%
mov_data.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
mov_data['budget']
# Out:
# 0       237000000
# 1       300000000
# 2       245000000
# 3       250000000
# 4       260000000
#           ...
# 4798       220000
# 4799         9000
# 4800            0
# 4801            0
# 4802            0
# Name: budget, Length: 4803, dtype: int64

# %%
mov_data['budget','original_title']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# F:\Anaconda\anaconda setup\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('budget', 'original_title')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-e8c0a421064a> in <module>
# ...

# %%
mov_data[['budget','original_title']]#for getting multiple column, store in list form
# Out:
#          budget                            original_title
# 0     237000000                                    Avatar
# 1     300000000  Pirates of the Caribbean: At World's End
# 2     245000000                                   Spectre
# 3     250000000                     The Dark Knight Rises
# 4     260000000                               John Carter
# ...         ...                                       ...
# 4798     220000                               El Mariachi
# 4799       9000                                 Newlyweds
# 4800          0                 Signed, Sealed, Delivered
# 4801          0                          Shanghai Calling
# 4802          0                         My Date with Drew
#
# [4803 rows x 2 columns]

# %%
type(mov_data['budget'])#series
# Out:
# pandas.core.series.Series

# %%
type(mov_data[['budget']])#dataframe:-when we write in list form
# Out:
# pandas.core.frame.DataFrame

# %%
mov_data[['original_title','original_language','vote_average','vote_count','runtime']]
# Out:
#                                 original_title original_language  \
# 0                                       Avatar                en
# 1     Pirates of the Caribbean: At World's End                en
# 2                                      Spectre                en
# 3                        The Dark Knight Rises                en
# 4                                  John Carter                en
# ...                                        ...               ...
# 4798                               El Mariachi                es
# 4799                                 Newlyweds                en
# 4800                 Signed, Sealed, Delivered                en
# 4801                          Shanghai Calling                en
# 4802                         My Date with Drew                en
#
#       vote_average  vote_count  runtime
# 0              7.2       11800    162.0
# 1              6.9        4500    169.0
# 2              6.3        4466    148.0
# ...

# %%
mov_data[['original_title','original_language','vote_average','vote_count','runtime']].head()
# Out:
#                              original_title original_language  vote_average  \
# 0                                    Avatar                en           7.2
# 1  Pirates of the Caribbean: At World's End                en           6.9
# 2                                   Spectre                en           6.3
# 3                     The Dark Knight Rises                en           7.6
# 4                               John Carter                en           6.1
#
#    vote_count  runtime
# 0       11800    162.0
# 1        4500    169.0
# 2        4466    148.0
# 3        9106    165.0
# 4        2124    132.0

# %% [markdown]
# ## selecting rows using [ ] bracket

# %%
mov_data.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
mov_data[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# F:\Anaconda\anaconda setup\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-f847156a1dfd> in <module>
# ----> 1 mov_data[0]
#
# ...

# %%
mov_data[0:1]#getting 1 row with index '0'
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
# ...

# %%
mov_data[2:5]#getting 3 row with index '2,3,4'
# Out:
#       budget                                             genres  \
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                       homepage      id  \
# 2  http://www.sonypictures.com/movies/spectre/  206647
# 3           http://www.thedarkknightrises.com/   49026
# 4         http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#           original_title                                           overview  \
# 2                Spectre  A cryptic message from Bond’s past sends him o...
# ...

# %%
data = mov_data[2:5]

# %%
type(data)#same type as mov_data
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#       budget                                             genres  \
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                       homepage      id  \
# 2  http://www.sonypictures.com/movies/spectre/  206647
# 3           http://www.thedarkknightrises.com/   49026
# 4         http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#           original_title                                           overview  \
# 2                Spectre  A cryptic message from Bond’s past sends him o...
# ...

# %%
data[['original_title','release_date']]
# Out:
#           original_title release_date
# 2                Spectre   2015-10-26
# 3  The Dark Knight Rises   2012-07-16
# 4            John Carter   2012-03-07

# %% [markdown]
# ## iloc

# %%
mov_data.head(10)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
mov_data['original_title']#selecting single column
# Out:
# 0                                         Avatar
# 1       Pirates of the Caribbean: At World's End
# 2                                        Spectre
# 3                          The Dark Knight Rises
# 4                                    John Carter
#                           ...
# 4798                                 El Mariachi
# 4799                                   Newlyweds
# 4800                   Signed, Sealed, Delivered
# 4801                            Shanghai Calling
# 4802                           My Date with Drew
# Name: original_title, Length: 4803, dtype: object

# %%
mov_data[['original_title','budget']]#selecting multiple column
# Out:
#                                 original_title     budget
# 0                                       Avatar  237000000
# 1     Pirates of the Caribbean: At World's End  300000000
# 2                                      Spectre  245000000
# 3                        The Dark Knight Rises  250000000
# 4                                  John Carter  260000000
# ...                                        ...        ...
# 4798                               El Mariachi     220000
# 4799                                 Newlyweds       9000
# 4800                 Signed, Sealed, Delivered          0
# 4801                          Shanghai Calling          0
# 4802                         My Date with Drew          0
#
# [4803 rows x 2 columns]

# %%
mov_data[0:1]#selecting row
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
# ...

# %%
mov_data[5:15]
# Out:
#        budget                                             genres  \
# 5   258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6   260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7   280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8   250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9   250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10  270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11  200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12  200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 13  255000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 14  225000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                              homepage      id  \
# 5     http://www.sonypictures.com/movies/spider-man3/     559
# 6        http://disney.go.com/disneypictures/tangled/   38757
# ...

# %%
#iloc
mov_data.head(5)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
mov_data.iloc[0]#selecting 0th row
# Out:
# budget                                                          237000000
# genres                  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                                      http://www.avatarmovie.com/
# id                                                                  19995
# keywords                [{"id": 1463, "name": "culture clash"}, {"id":...
# original_language                                                      en
# original_title                                                     Avatar
# overview                In the 22nd century, a paraplegic Marine is di...
# popularity                                                        150.438
# production_companies    [{"name": "Ingenious Film Partners", "id": 289...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2009-12-10
# revenue                                                        2787965087
# ...

# %%
type(mov_data.iloc[0])
# Out:
# pandas.core.series.Series

# %%
mov_data.iloc[0:5]
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
type(mov_data.iloc[0:5])
# Out:
# pandas.core.frame.DataFrame

# %%
mov_data.iloc[[0,5,10,15]]#selecting index
# Out:
#        budget                                             genres  \
# 0   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5   258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 10  270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 15  225000000  [{"id": 12, "name": "Adventure"}, {"id": 10751...
#
#                                            homepage     id  \
# 0                       http://www.avatarmovie.com/  19995
# 5   http://www.sonypictures.com/movies/spider-man3/    559
# 10                          http://www.superman.com   1452
# 15                                              NaN   2454
#
#                                              keywords original_language  \
# 0   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 5   [{"id": 851, "name": "dual identity"}, {"id": ...                en
# 10  [{"id": 83, "name": "saving the world"}, {"id"...                en
# ...

# %%
mov_data.iloc[[0,5,10,15],[6,1]]#selecting row 0,5,10,15 and column 6,1
# Out:
#                               original_title  \
# 0                                     Avatar
# 5                               Spider-Man 3
# 10                          Superman Returns
# 15  The Chronicles of Narnia: Prince Caspian
#
#                                                genres
# 0   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5   [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 10  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 15  [{"id": 12, "name": "Adventure"}, {"id": 10751...

# %%
mov_data.iloc[[0,5,10,15],0:7]
# Out:
#        budget                                             genres  \
# 0   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5   258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 10  270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 15  225000000  [{"id": 12, "name": "Adventure"}, {"id": 10751...
#
#                                            homepage     id  \
# 0                       http://www.avatarmovie.com/  19995
# 5   http://www.sonypictures.com/movies/spider-man3/    559
# 10                          http://www.superman.com   1452
# 15                                              NaN   2454
#
#                                              keywords original_language  \
# 0   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 5   [{"id": 851, "name": "dual identity"}, {"id": ...                en
# 10  [{"id": 83, "name": "saving the world"}, {"id"...                en
# ...

# %% [markdown]
# ## Loc

# %%
mov_data.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
mov_data.loc[3]#seleting 3rd row
# Out:
# budget                                                          250000000
# genres                  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# homepage                               http://www.thedarkknightrises.com/
# id                                                                  49026
# keywords                [{"id": 849, "name": "dc comics"}, {"id": 853,...
# original_language                                                      en
# original_title                                      The Dark Knight Rises
# overview                Following the death of District Attorney Harve...
# popularity                                                        112.313
# production_companies    [{"name": "Legendary Pictures", "id": 923}, {"...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2012-07-16
# revenue                                                        1084939099
# ...

# %%
# loc:-mov_data.loc[0:3], it select index from 0 to 3 but in
# iloc:-mov_data.iloc[0:3], it select index from 0 to 2 that is the diff b/w iloc & loc 
mov_data.loc[0:3]
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
#
# ...

# %%
#other use of loc
#changing index
mov_data = pd.read_csv("tmdb_5000_movies.csv", index_col = 'original_title' )
mov_data
# Out:
#                                              budget  \
# original_title
# Avatar                                    237000000
# Pirates of the Caribbean: At World's End  300000000
# Spectre                                   245000000
# The Dark Knight Rises                     250000000
# John Carter                               260000000
# ...                                             ...
# El Mariachi                                  220000
# Newlyweds                                      9000
# Signed, Sealed, Delivered                         0
# Shanghai Calling                                  0
# My Date with Drew                                 0
#
#                                                                                      genres  \
# original_title
# Avatar                                    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# Pirates of the Caribbean: At World's End  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
#now we simple getting inform'n related to in movie by just typing name
mov_data.loc['Avatar']
# Out:
# budget                                                          237000000
# genres                  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                                      http://www.avatarmovie.com/
# id                                                                  19995
# keywords                [{"id": 1463, "name": "culture clash"}, {"id":...
# original_language                                                      en
# overview                In the 22nd century, a paraplegic Marine is di...
# popularity                                                        150.438
# production_companies    [{"name": "Ingenious Film Partners", "id": 289...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2009-12-10
# revenue                                                        2787965087
# runtime                                                               162
# ...

# %%
mov_data.loc[['Avatar','Spectre']]#for more than one data
# Out:
#                    budget                                             genres  \
# original_title
# Avatar          237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# Spectre         245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                                    homepage      id  \
# original_title
# Avatar                          http://www.avatarmovie.com/   19995
# Spectre         http://www.sonypictures.com/movies/spectre/  206647
#
#                                                          keywords  \
# original_title
# Avatar          [{"id": 1463, "name": "culture clash"}, {"id":...
# Spectre         [{"id": 470, "name": "spy"}, {"id": 818, "name...
#
#                original_language  \
# original_title
# Avatar                        en
# Spectre                       en
#
#                                                          overview  popularity  \
# original_title
# ...

# %%
mov_data.loc[['Avatar','Spectre'], ['budget','original_language']]#selecting row with perticular column
# Out:
#                    budget original_language
# original_title
# Avatar          237000000                en
# Spectre         245000000                en

# %% [markdown]
# ## series

# %%
mov_data=pd.read_csv("tmdb_5000_movies.csv")
mov_data
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
mov_data.head(10)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
#series:-selecting one particular column
mov_data['budget']
# Out:
# 0       237000000
# 1       300000000
# 2       245000000
# 3       250000000
# 4       260000000
#           ...
# 4798       220000
# 4799         9000
# 4800            0
# 4801            0
# 4802            0
# Name: budget, Length: 4803, dtype: int64

# %%
type(mov_data['budget'])
# Out:
# pandas.core.series.Series

# %%
#numerical series
ser = mov_data['budget']

# %%
ser.head()
# Out:
# 0    237000000
# 1    300000000
# 2    245000000
# 3    250000000
# 4    260000000
# Name: budget, dtype: int64

# %%
ser.tail()
# Out:
# 4798    220000
# 4799      9000
# 4800         0
# 4801         0
# 4802         0
# Name: budget, dtype: int64

# %%
ser.head(10)
# Out:
# 0    237000000
# 1    300000000
# 2    245000000
# 3    250000000
# 4    260000000
# 5    258000000
# 6    260000000
# 7    280000000
# 8    250000000
# 9    250000000
# Name: budget, dtype: int64

# %%
ser.tail(10)
# Out:
# 4793         0
# 4794         0
# 4795         0
# 4796      7000
# 4797         0
# 4798    220000
# 4799      9000
# 4800         0
# 4801         0
# 4802         0
# Name: budget, dtype: int64

# %%
ser.dtype
# Out:
# dtype('int64')

# %%
mov_data.info()#we can't use same method with series
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
ser.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-58d459bcf136> in <module>
# ----> 1 ser.info()
#
# F:\Anaconda\anaconda setup\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
ser.shape
# Out:
# (4803,)

# %%
ser.size
# Out:
# 4803

# %%
ser.describe()
# Out:
# count    4.803000e+03
# mean     2.904504e+07
# std      4.072239e+07
# min      0.000000e+00
# 25%      7.900000e+05
# 50%      1.500000e+07
# 75%      4.000000e+07
# max      3.800000e+08
# Name: budget, dtype: float64

# %%
ser.index
# Out:
# RangeIndex(start=0, stop=4803, step=1)

# %%
import pandas as pd

# %%
mov_data=pd.read_csv("tmdb_5000_movies.csv")

# %%
mov_data
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
ser = mov_data['runtime']

# %%
ser
# Out:
# 0       162.0
# 1       169.0
# 2       148.0
# 3       165.0
# 4       132.0
#         ...
# 4798     81.0
# 4799     85.0
# 4800    120.0
# 4801     98.0
# 4802     90.0
# Name: runtime, Length: 4803, dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
ser.head()
# Out:
# 0    162.0
# 1    169.0
# 2    148.0
# 3    165.0
# 4    132.0
# Name: runtime, dtype: float64

# %%
ser.sum()
# Out:
# 513111.0

# %%
ser.size#count missing value,undefined values
# Out:
# 4803

# %%
ser.count()
# Out:
# 4801

# %%
ser.size-ser.count()#no of missing,undefined values
# Out:
# 2

# %%
ser.mean()
# Out:
# 106.87585919600083

# %%
ser.std()
# Out:
# 22.611934588844207

# %%
ser.median()
# Out:
# 103.0

# %%
ser.min()
# Out:
# 0.0

# %%
ser.max()
# Out:
# 338.0

# %%
#mathod which is only use with pandas series,not with pandas data frame
ser.unique()#count all unique value
# Out:
# array([162., 169., 148., 165., 132., 139., 100., 141., 153., 151., 154.,
#        106., 149., 143., 150., 136., 144., 140., 161., 113., 187., 194.,
#        147., 131., 124., 127., 130., 108., 104., 142., 125., 114., 103.,
#        115., 137., 116., 122.,  93.,  98.,  91., 158.,  96., 109., 152.,
#         94., 126., 112., 123., 135., 118.,  97., 119., 102., 120., 121.,
#        166.,  99., 183., 175., 138., 157.,  92., 101., 111.,  89., 105.,
#        107., 129.,  88.,  85., 163., 133.,  95.,  90., 110., 128., 156.,
#        117., 146.,  82.,  78., 134., 170.,  76., 178.,  84., 155., 145.,
#        180., 172., 167., 201., 179.,  83.,  87.,  80.,  74.,  81., 177.,
#         86., 164., 159., 191., 189., 214.,   0.,  75., 192., 160., 219.,
#        248., 188., 202., 173., 195.,  77.,  79.,  63., 229., 193., 254.,
#         72.,  68., 199., 181., 242., 338.,  73., 216., 276.,  nan, 200.,
#         69., 197., 184., 176., 185., 171., 174.,  46.,  53.,  42., 240.,
# ...

# %%
ser.nunique()#no of unique items
# Out:
# 156

# %%
len(ser.unique())#one extra item which is 'nan' value
# Out:
# 157

# %%
ser.nunique(dropna = True)
# Out:
# 156

# %%
ser.nunique(dropna = False)
# Out:
# 157

# %%
#we can nunique mathod with dataframe but not unique mathod
mov_data.nunique()
# Out:
# budget                   436
# genres                  1175
# homepage                1691
# id                      4803
# keywords                4222
# original_language         37
# original_title          4801
# overview                4800
# popularity              4802
# production_companies    3697
# production_countries     469
# release_date            3280
# revenue                 3297
# runtime                  156
# spoken_languages         544
# status                     3
# tagline                 3944
# title                   4800
# vote_average              71
# vote_count              1609
# dtype: int64

# %%
#value_counts mathod only use with series
ser.value_counts()#it show 90 min times runtime movies are 163
# Out:
# 90.0     163
# 100.0    149
# 98.0     140
# 97.0     133
# 95.0     123
#         ...
# 338.0      1
# 53.0       1
# 214.0      1
# 194.0      1
# 179.0      1
# Name: runtime, Length: 156, dtype: int64

# %%
ser.value_counts(ascending = True)
# Out:
# 179.0      1
# 194.0      1
# 214.0      1
# 53.0       1
# 338.0      1
#         ...
# 95.0     123
# 97.0     133
# 98.0     140
# 100.0    149
# 90.0     163
# Name: runtime, Length: 156, dtype: int64

# %%
ser.value_counts(ascending = False)
# Out:
# 90.0     163
# 100.0    149
# 98.0     140
# 97.0     133
# 95.0     123
#         ...
# 338.0      1
# 53.0       1
# 214.0      1
# 194.0      1
# 179.0      1
# Name: runtime, Length: 156, dtype: int64

# %%
ser.value_counts(ascending = False, bins =3)#it show 3245 movies are interval of (-0.339, 112.667]
# Out:
# (-0.339, 112.667]     3245
# (112.667, 225.333]    1548
# (225.333, 338.0]         8
# Name: runtime, dtype: int64

# %%
ser.value_counts(ascending = False, bins =5)
# Out:
# (67.6, 135.2]     4365
# (135.2, 202.8]     375
# (-0.339, 67.6]      48
# (202.8, 270.4]      11
# (270.4, 338.0]       2
# Name: runtime, dtype: int64

# %% [markdown]
# ## diff way to create series

# %%
import pandas as pd

# %%
ser_data =pd.read_csv("tmdb_5000_movies.csv")

# %%
ser_data
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
#type 1
ser1 = ser_data['runtime']

# %%
ser1
# Out:
# 0       162.0
# 1       169.0
# 2       148.0
# 3       165.0
# 4       132.0
#         ...
# 4798     81.0
# 4799     85.0
# 4800    120.0
# 4801     98.0
# 4802     90.0
# Name: runtime, Length: 4803, dtype: float64

# %%
type(ser1)
# Out:
# pandas.core.series.Series

# %%
#type 2:- own series with the use list
anime = ['My Hero Academia','Death note','Sword Art Online','One Punch Man','Domostic Girlfriend','yurl on ice','Doramon']
genre = ['shounen','shounen','Action Adventure','action','shounen/shoujo','sports/josel','kodomemuke']

# %%
anime_series = pd.Series(anime)

# %%
anime_series
# Out:
# 0       My Hero Academia
# 1             Death note
# 2       Sword Art Online
# 3          One Punch Man
# 4    Domostic Girlfriend
# 5            yurl on ice
# 6                Doramon
# dtype: object

# %%
anime_series = pd.Series(anime, name='anime genre')

# %%
anime_series
# Out:
# 0       My Hero Academia
# 1             Death note
# 2       Sword Art Online
# 3          One Punch Man
# 4    Domostic Girlfriend
# 5            yurl on ice
# 6                Doramon
# Name: anime genre, dtype: object

# %%
type(anime_series)
# Out:
# pandas.core.series.Series

# %%
anime_series2 = pd.Series(genre, index=anime, name='anime genre')

# %%
anime_series2
# Out:
# My Hero Academia                shounen
# Death note                      shounen
# Sword Art Online       Action Adventure
# One Punch Man                    action
# Domostic Girlfriend      shounen/shoujo
# yurl on ice                sports?josel
# Doramon                      kodomemuke
# Name: anime genre, dtype: object

# %%
#type 2:- own series with the use of numpy array,tuples
import numpy as np
anime = np.array(['My Hero Academia','Death note','Sword Art Online','One Punch Man','Domostic Girlfriend','yurl on ice','Doramon'])#array
genre = ('shounen','shounen','Action Adventure','action','shounen/shoujo','sports/josel','kodomemuke')#tuples

# %%
anime_ser = pd.Series(anime, name='anime genre')

# %%
anime_ser
# Out:
# 0       My Hero Academia
# 1             Death note
# 2       Sword Art Online
# 3          One Punch Man
# 4    Domostic Girlfriend
# 5            yurl on ice
# 6                Doramon
# Name: anime genre, dtype: object

# %%
anime_ser2 = pd.Series(genre, index=anime, name='anime genre')

# %%
anime_ser2
# Out:
# My Hero Academia                shounen
# Death note                      shounen
# Sword Art Online       Action Adventure
# One Punch Man                    action
# Domostic Girlfriend      shounen/shoujo
# yurl on ice                sports/josel
# Doramon                      kodomemuke
# Name: anime genre, dtype: object

# %%
# with the help of dictionary
dic = {
    "My Hero Academia"    :            "shounen",
    "Death note"          :            "shounen",
    "Sword Art Online"    :   "Action Adventure",
    "One Punch Man"       :             "action",
    "Domostic Girlfriend" :     "shounen/shoujo",
    "yurl on ice"         :       "sports/josel",
    "Doramon"             :          "kodomemuke"
}

# %%
ani_s = pd.Series(dic, name='anime genre')

# %%
ani_s
# Out:
# My Hero Academia                shounen
# Death note                      shounen
# Sword Art Online       Action Adventure
# One Punch Man                    action
# Domostic Girlfriend      shounen/shoujo
# yurl on ice                sports/josel
# Doramon                      kodomemuke
# Name: anime genre, dtype: object

# %%
# another way to create series
series =pd.read_csv("tmdb_5000_movies.csv", usecols = ['runtime'], squeeze = True)

# %%
series
# Out:
# 0       162.0
# 1       169.0
# 2       148.0
# 3       165.0
# 4       132.0
#         ...
# 4798     81.0
# 4799     85.0
# 4800    120.0
# 4801     98.0
# 4802     90.0
# Name: runtime, Length: 4803, dtype: float64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## sort series

# %%
import pandas as pd

# %%
dic = {
    1:'one',
    3:'three',
    2:'two',
    4:'four'
}

# %%
seri = pd.Series(dic , name='numbers')

# %%
seri
# Out:
# 1      one
# 3    three
# 2      two
# 4     four
# Name: numbers, dtype: object

# %%
#we do sorting from 2 ways, by index or by values
seri.sort_index()#by index:-sort according to index,it doesn't sort actual series
# Out:
# 1      one
# 2      two
# 3    three
# 4     four
# Name: numbers, dtype: object

# %%
seri.sort_index(ascending=True)
# Out:
# 1      one
# 2      two
# 3    three
# 4     four
# Name: numbers, dtype: object

# %%
seri.sort_index(ascending=False)
# Out:
# 4     four
# 3    three
# 2      two
# 1      one
# Name: numbers, dtype: object

# %%
seri#actual series is not sort
# Out:
# 1      one
# 3    three
# 2      two
# 4     four
# Name: numbers, dtype: object

# %%
seri.sort_index(ascending=True, inplace=True)#for sorting actual series

# %%
seri
# Out:
# 1      one
# 2      two
# 3    three
# 4     four
# Name: numbers, dtype: object

# %%
seri.sort_values()#by values:-sort according to values(alphabetically)
# Out:
# 4     four
# 1      one
# 3    three
# 2      two
# Name: numbers, dtype: object

# %%
seri.sort_values(ascending=True)
# Out:
# 4     four
# 1      one
# 3    three
# 2      two
# Name: numbers, dtype: object

# %%
seri.sort_values(ascending=False)
# Out:
# 2      two
# 3    three
# 1      one
# 4     four
# Name: numbers, dtype: object

# %%
seri.sort_values(ascending=True, inplace=True)

# %%
seri
# Out:
# 4     four
# 1      one
# 3    three
# 2      two
# Name: numbers, dtype: object

# %% [markdown]
# ## series to list or array conversion

# %%
import pandas as pd

# %%
dict = {
    1:'one',
    3:'three',
    2:'two',
    4:'four'
}

# %%
series = pd.Series(dict , name='numbers')

# %%
series
# Out:
# 1      one
# 3    three
# 2      two
# 4     four
# Name: numbers, dtype: object

# %%
series.tolist()#converting to list
# Out:
# ['one', 'three', 'two', 'four']

# %%
series.values#converting into array
# Out:
# array(['one', 'three', 'two', 'four'], dtype=object)

# %% [markdown]
# ## Largest and smallest

# %%
import pandas as pd

# %%
guitar_dic = {
             'Yamsha F310'          : 8500,
             'Faith Apollo Venus'   : 30000,
             'Taylor 214 CE'        : 250000,
             'Baton Rounge X6C'     : 40000,
             'PRS SE'               : 42000,
             'Lakewood'             : 300000
            }

# %%
guitar_price = pd.Series(guitar_dic, name= 'price')

# %%
guitar_price
# Out:
# Yamsha F310             8500
# Faith Apollo Venus     30000
# Taylor 214 CE         250000
# Baton Rounge X6C       40000
# PRS SE                 42000
# Lakewood              300000
# Name: price, dtype: int64

# %%
guitar_price.nsmallest()#gives data of top5 smallest price guitar
# Out:
# Yamsha F310             8500
# Faith Apollo Venus     30000
# Baton Rounge X6C       40000
# PRS SE                 42000
# Taylor 214 CE         250000
# Name: price, dtype: int64

# %%
guitar_price.nsmallest(n=2)
# Out:
# Yamsha F310            8500
# Faith Apollo Venus    30000
# Name: price, dtype: int64

# %%
guitar_price.nsmallest(n=6)
# Out:
# Yamsha F310             8500
# Faith Apollo Venus     30000
# Baton Rounge X6C       40000
# PRS SE                 42000
# Taylor 214 CE         250000
# Lakewood              300000
# Name: price, dtype: int64

# %%
guitar_price.nsmallest().index[0]#gives name of smallest price guitar
# Out:
# 'Yamsha F310'

# %%
guitar_price.nlargest()#top5 largest price guitar
# Out:
# Lakewood              300000
# Taylor 214 CE         250000
# PRS SE                 42000
# Baton Rounge X6C       40000
# Faith Apollo Venus     30000
# Name: price, dtype: int64

# %%
guitar_price.nlargest(n=3)
# Out:
# Lakewood         300000
# Taylor 214 CE    250000
# PRS SE            42000
# Name: price, dtype: int64

# %%
guitar_price.nlargest().index[0]
# Out:
# 'Lakewood'

# %%
guitar_price.idxmin()#gives index of smallest value
# Out:
# 'Yamsha F310'

# %%
guitar_price.idxmax()#gives index of largest value
# Out:
# 'Lakewood'

# %% [markdown]
# # Idex Object
# ## Reset index, set index,indexing and slicing of index object, get_loc, is_unique,create index object from scratch

# %%
import pandas as pd

# %%
data_frame = pd.read_csv("tmdb_5000_movies.csv",index_col = 'original_title')

# %%
data_frame.head()
# Out:
#                                              budget  \
# original_title
# Avatar                                    237000000
# Pirates of the Caribbean: At World's End  300000000
# Spectre                                   245000000
# The Dark Knight Rises                     250000000
# John Carter                               260000000
#
#                                                                                      genres  \
# original_title
# Avatar                                    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# Pirates of the Caribbean: At World's End  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# Spectre                                   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# The Dark Knight Rises                     [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# John Carter                               [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
# ...

# %%
data_frame.reset_index()#don't change original data frame
# Out:
#                                 original_title     budget  \
# 0                                       Avatar  237000000
# 1     Pirates of the Caribbean: At World's End  300000000
# 2                                      Spectre  245000000
# 3                        The Dark Knight Rises  250000000
# 4                                  John Carter  260000000
# ...                                        ...        ...
# 4798                               El Mariachi     220000
# 4799                                 Newlyweds       9000
# 4800                 Signed, Sealed, Delivered          0
# 4801                          Shanghai Calling          0
# 4802                         My Date with Drew          0
#
#                                                  genres  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...

# %%
data_frame
# Out:
#                                              budget  \
# original_title
# Avatar                                    237000000
# Pirates of the Caribbean: At World's End  300000000
# Spectre                                   245000000
# The Dark Knight Rises                     250000000
# John Carter                               260000000
# ...                                             ...
# El Mariachi                                  220000
# Newlyweds                                      9000
# Signed, Sealed, Delivered                         0
# Shanghai Calling                                  0
# My Date with Drew                                 0
#
#                                                                                      genres  \
# original_title
# Avatar                                    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# Pirates of the Caribbean: At World's End  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
data_frame.reset_index(inplace=True)# change original data frame

# %%
data_frame
# Out:
#       index                            original_title     budget  \
# 0         0                                    Avatar  237000000
# 1         1  Pirates of the Caribbean: At World's End  300000000
# 2         2                                   Spectre  245000000
# 3         3                     The Dark Knight Rises  250000000
# 4         4                               John Carter  260000000
# ...     ...                                       ...        ...
# 4798   4798                               El Mariachi     220000
# 4799   4799                                 Newlyweds       9000
# 4800   4800                 Signed, Sealed, Delivered          0
# 4801   4801                          Shanghai Calling          0
# 4802   4802                         My Date with Drew          0
#
#                                                  genres      id  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# ...

# %%
data_frame.set_index('homepage')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-190c3052ed00> in <module>
# ----> 1 data_frame.set_index('homepage')
#
# F:\Anaconda\anaconda setup\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['homepage'] are in the columns"

# %%
data_frame.set_index('homepage', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-5991599f502c> in <module>
# ----> 1 data_frame.set_index('homepage', inplace=True)
#
# F:\Anaconda\anaconda setup\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['homepage'] are in the columns"

# %%
data_frame.head()
# Out:
#    index                            original_title     budget  \
# 0      0                                    Avatar  237000000
# 1      1  Pirates of the Caribbean: At World's End  300000000
# 2      2                                   Spectre  245000000
# 3      3                     The Dark Knight Rises  250000000
# 4      4                               John Carter  260000000
#
#                                               genres      id  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
data_frame.set_index('original_title')
# Out:
#                                           index     budget  \
# original_title
# Avatar                                        0  237000000
# Pirates of the Caribbean: At World's End      1  300000000
# Spectre                                       2  245000000
# The Dark Knight Rises                         3  250000000
# John Carter                                   4  260000000
# ...                                         ...        ...
# El Mariachi                                4798     220000
# Newlyweds                                  4799       9000
# Signed, Sealed, Delivered                  4800          0
# Shanghai Calling                           4801          0
# My Date with Drew                          4802          0
#
#                                                                                      genres  \
# original_title
# Avatar                                    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...

# %%
data_frame.set_index('original_title',inplace=True)

# %%
data_frame.head()
# Out:
#                                           index     budget  \
# original_title
# Avatar                                        0  237000000
# Pirates of the Caribbean: At World's End      1  300000000
# Spectre                                       2  245000000
# The Dark Knight Rises                         3  250000000
# John Carter                                   4  260000000
#
#                                                                                      genres  \
# original_title
# Avatar                                    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# Pirates of the Caribbean: At World's End  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# Spectre                                   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# The Dark Knight Rises                     [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# John Carter                               [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
# ...

# %%
#indexing
data_frame.index
# Out:
# Index(['Avatar', 'Pirates of the Caribbean: At World's End', 'Spectre',
#        'The Dark Knight Rises', 'John Carter', 'Spider-Man 3', 'Tangled',
#        'Avengers: Age of Ultron', 'Harry Potter and the Half-Blood Prince',
#        'Batman v Superman: Dawn of Justice',
#        ...
#        'On The Downlow', 'Sanctuary: Quite a Conundrum', 'Bang', 'Primer',
#        'Cavite', 'El Mariachi', 'Newlyweds', 'Signed, Sealed, Delivered',
#        'Shanghai Calling', 'My Date with Drew'],
#       dtype='object', name='original_title', length=4803)

# %%
data_frame.columns
# Out:
# Index(['index', 'budget', 'genres', 'id', 'keywords', 'original_language',
#        'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
type(data_frame.index)
# Out:
# pandas.core.indexes.base.Index

# %%
type(data_frame.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
#slicing
data_frame.index[2]
# Out:
# 'Spectre'

# %%
data_frame.columns[2]
# Out:
# 'genres'

# %%
data_frame.columns[-3]
# Out:
# 'title'

# %%
data_frame.columns[-2:]
# Out:
# Index(['vote_average', 'vote_count'], dtype='object')

# %%
data_frame.index[-2:]
# Out:
# Index(['Shanghai Calling', 'My Date with Drew'], dtype='object', name='original_title')

# %%
#get_loc
data_frame.index.get_loc('Spectre')
# Out:
# 2

# %%
data_frame.columns.get_loc('genres')
# Out:
# 2

# %%
#is_unique:-it shown all the index and column are unique or not
data_frame.columns.is_unique
# Out:
# True

# %%
data_frame.index.is_unique
# Out:
# False

# %%
#creaating index object
xyz = pd.Index(['A','B','C'])

# %%
xyz
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
xyz.is_unique
# Out:
# True

# %%
Ser =pd.Series([1,2,3],index=xyz)

# %%
Ser
# Out:
# A    1
# B    2
# C    3
# dtype: int64

# %% [markdown]
# ## Filter Data

# %%
import pandas as pd

# %%
df = pd.read_csv("master.csv")

# %%
df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
df.country
# Out:
# 0           Albania
# 1           Albania
# 2           Albania
# 3           Albania
# 4           Albania
#             ...
# 27815    Uzbekistan
# 27816    Uzbekistan
# 27817    Uzbekistan
# 27818    Uzbekistan
# 27819    Uzbekistan
# Name: country, Length: 27820, dtype: object

# %%
df.country.unique()
# Out:
# array(['Albania', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Barbados', 'Belarus', 'Belgium', 'Belize',
#        'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Cabo Verde',
#        'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Croatia', 'Cuba',
#        'Cyprus', 'Czech Republic', 'Denmark', 'Dominica', 'Ecuador',
#        'El Salvador', 'Estonia', 'Fiji', 'Finland', 'France', 'Georgia',
#        'Germany', 'Greece', 'Grenada', 'Guatemala', 'Guyana', 'Hungary',
#        'Iceland', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Kazakhstan', 'Kiribati', 'Kuwait', 'Kyrgyzstan', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Macau', 'Maldives', 'Malta',
#        'Mauritius', 'Mexico', 'Mongolia', 'Montenegro', 'Netherlands',
#        'New Zealand', 'Nicaragua', 'Norway', 'Oman', 'Panama', 'Paraguay',
#        'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
# ...

# %%
df.country == 'Israel'#True say Israel in this row, False say Avatar is not here
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 27815    False
# 27816    False
# 27817    False
# 27818    False
# 27819    False
# Name: country, Length: 27820, dtype: bool

# %%
df[df.country == 'Israel']#gives all the data related to israel
# Out:
#       country  year     sex          age  suicides_no  population  \
# 12416  Israel  1985    male    75+ years           24       66600
# 12417  Israel  1985    male  55-74 years           48      249100
# 12418  Israel  1985  female    75+ years           10       75500
# 12419  Israel  1985    male  35-54 years           41      396400
# 12420  Israel  1985  female  55-74 years           28      290900
# ...       ...   ...     ...          ...          ...         ...
# 12783  Israel  2015  female  25-34 years           13      581972
# 12784  Israel  2015  female  35-54 years           20      967412
# 12785  Israel  2015  female  15-24 years            8      617440
# 12786  Israel  2015    male   5-14 years            2      770443
# 12787  Israel  2015  female   5-14 years            1      733603
#
#        suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 12416              36.04   Israel1985         0.768     27,493,591,484
# ...

# %%
type(df.country == 'Israel')
# Out:
# pandas.core.series.Series

# %%
(df.country == 'Israel').dtype
# Out:
# dtype('bool')

# %%
df[(df.country == 'Israel') & (df.year==2014)]#give data of israel of year is 2014
# Out:
#       country  year     sex          age  suicides_no  population  \
# 12764  Israel  2014    male    75+ years           32      164959
# 12765  Israel  2014    male  35-54 years          125      925543
# 12766  Israel  2014    male  55-74 years           54      577076
# 12767  Israel  2014    male  25-34 years           41      580208
# 12768  Israel  2014    male  15-24 years           35      633544
# 12769  Israel  2014  female    75+ years           11      236381
# 12770  Israel  2014  female  55-74 years           24      645102
# 12771  Israel  2014  female  35-54 years           29      949566
# 12772  Israel  2014  female  25-34 years           13      576407
# 12773  Israel  2014  female  15-24 years           10      607031
# 12774  Israel  2014    male   5-14 years            7      753317
# 12775  Israel  2014  female   5-14 years            1      717118
#
#        suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
mask1 = df.country == 'Israel'
mask2 = df.year==2014
mask3 = df.year==2015
mask4 = df.sex== 'male'
df[mask1 & mask4 &(mask2 | mask3)]
# Out:
#       country  year   sex          age  suicides_no  population  \
# 12764  Israel  2014  male    75+ years           32      164959
# 12765  Israel  2014  male  35-54 years          125      925543
# 12766  Israel  2014  male  55-74 years           54      577076
# 12767  Israel  2014  male  25-34 years           41      580208
# 12768  Israel  2014  male  15-24 years           35      633544
# 12774  Israel  2014  male   5-14 years            7      753317
# 12776  Israel  2015  male    75+ years           30      168826
# 12777  Israel  2015  male  55-74 years           65      595247
# 12778  Israel  2015  male  35-54 years           92      944406
# 12779  Israel  2015  male  25-34 years           45      586251
# 12781  Israel  2015  male  15-24 years           35      644674
# 12786  Israel  2015  male   5-14 years            2      770443
#
#        suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
f_df = df[mask1 & mask4 &(mask2 | mask3)]#filter data

# %%
f_df
# Out:
#       country  year   sex          age  suicides_no  population  \
# 12764  Israel  2014  male    75+ years           32      164959
# 12765  Israel  2014  male  35-54 years          125      925543
# 12766  Israel  2014  male  55-74 years           54      577076
# 12767  Israel  2014  male  25-34 years           41      580208
# 12768  Israel  2014  male  15-24 years           35      633544
# 12774  Israel  2014  male   5-14 years            7      753317
# 12776  Israel  2015  male    75+ years           30      168826
# 12777  Israel  2015  male  55-74 years           65      595247
# 12778  Israel  2015  male  35-54 years           92      944406
# 12779  Israel  2015  male  25-34 years           45      586251
# 12781  Israel  2015  male  15-24 years           35      644674
# 12786  Israel  2015  male   5-14 years            2      770443
#
#        suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
f_df = df.loc[mask1 & mask4 &(mask2 | mask3),['country','year','sex','age','suicides_no']]

# %%
f_df
# Out:
#       country  year   sex          age  suicides_no
# 12764  Israel  2014  male    75+ years           32
# 12765  Israel  2014  male  35-54 years          125
# 12766  Israel  2014  male  55-74 years           54
# 12767  Israel  2014  male  25-34 years           41
# 12768  Israel  2014  male  15-24 years           35
# 12774  Israel  2014  male   5-14 years            7
# 12776  Israel  2015  male    75+ years           30
# 12777  Israel  2015  male  55-74 years           65
# 12778  Israel  2015  male  35-54 years           92
# 12779  Israel  2015  male  25-34 years           45
# 12781  Israel  2015  male  15-24 years           35
# 12786  Israel  2015  male   5-14 years            2

# %%
f_df.sum().suicides_no
# Out:
# 563

# %%
Df = pd.read_csv("master.csv")

# %%
Df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
#data above yr 2010
Mask1 = df.year>2010
#data b/w 2000 to 2010
Mask2 = df.year.between(2000,2010)
#data of yr 2000,2010
Mask3 = df.year.isin([2000, 2010])

# %%
Df.loc[Mask1]
# Out:
#                    country  year     sex          age  suicides_no  \
# 540    Antigua and Barbuda  2012  female  15-24 years            0
# 541    Antigua and Barbuda  2012  female  25-34 years            0
# 542    Antigua and Barbuda  2012  female  35-54 years            0
# 543    Antigua and Barbuda  2012  female   5-14 years            0
# 544    Antigua and Barbuda  2012  female  55-74 years            0
# ...                    ...   ...     ...          ...          ...
# 27815           Uzbekistan  2014  female  35-54 years          107
# 27816           Uzbekistan  2014  female    75+ years            9
# 27817           Uzbekistan  2014    male   5-14 years           60
# 27818           Uzbekistan  2014  female   5-14 years           44
# 27819           Uzbekistan  2014  female  55-74 years           21
#
#        population  suicides/100k pop             country-year  HDI for year  \
# 540          8435               0.00  Antigua and Barbuda2012         0.781
# ...

# %%
Df.loc[Mask2]
# Out:
#           country  year     sex          age  suicides_no  population  \
# 132       Albania  2000    male  25-34 years           17      232000
# 133       Albania  2000    male  55-74 years           10      177400
# 134       Albania  2000  female    75+ years            2       37800
# 135       Albania  2000    male    75+ years            1       24900
# 136       Albania  2000  female  15-24 years            6      263900
# ...           ...   ...     ...          ...          ...         ...
# 27767  Uzbekistan  2010  female  35-54 years          101     3339076
# 27768  Uzbekistan  2010    male   5-14 years           48     2751752
# 27769  Uzbekistan  2010  female    75+ years            5      322899
# 27770  Uzbekistan  2010  female  55-74 years           16     1161422
# 27771  Uzbekistan  2010  female   5-14 years           30     2627344
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
Df.loc[Mask3]
# Out:
#           country  year     sex          age  suicides_no  population  \
# 132       Albania  2000    male  25-34 years           17      232000
# 133       Albania  2000    male  55-74 years           10      177400
# 134       Albania  2000  female    75+ years            2       37800
# 135       Albania  2000    male    75+ years            1       24900
# 136       Albania  2000  female  15-24 years            6      263900
# ...           ...   ...     ...          ...          ...         ...
# 27767  Uzbekistan  2010  female  35-54 years          101     3339076
# 27768  Uzbekistan  2010    male   5-14 years           48     2751752
# 27769  Uzbekistan  2010  female    75+ years            5      322899
# 27770  Uzbekistan  2010  female  55-74 years           16     1161422
# 27771  Uzbekistan  2010  female   5-14 years           30     2627344
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
Df.loc[~Mask3]#all data except 2000,2010
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
f_Df = Df.loc[~Mask3]

# %%
f_Df.year.unique()
# Out:
# array([1987, 1988, 1989, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 1985, 1986,
#        1990, 1991, 2012, 2013, 2014, 2015, 2011, 2016], dtype=int64)

# %%
#check 2010 to 2014 male female sucide case 
# for switzerland 
Mask4 = Df.year.between(2010,2014)
Mask5 = Df.sex == 'male'
Mask6 = Df.sex == 'female'
Mask7 = Df.country == 'Switzerland'
Mask8 = Df.age == '15-24 years'
F_Df = Df.loc[Mask4 & Mask5 & Mask7 & Mask8, ['country','year','sex','age','suicides_no']]

# %%
F_Df
# Out:
#            country  year   sex          age  suicides_no
# 24911  Switzerland  2010  male  15-24 years           47
# 24922  Switzerland  2011  male  15-24 years           67
# 24933  Switzerland  2012  male  15-24 years           65
# 24947  Switzerland  2013  male  15-24 years           52
# 24959  Switzerland  2014  male  15-24 years           48

# %%
F_Df.sum().suicides_no
# Out:
# 279

# %%
F_DF = Df.loc[Mask4 & Mask6 & Mask7 & Mask8, ['country','year','sex','age','suicides_no']]

# %%
F_DF
# Out:
#            country  year     sex          age  suicides_no
# 24915  Switzerland  2010  female  15-24 years           15
# 24927  Switzerland  2011  female  15-24 years           15
# 24939  Switzerland  2012  female  15-24 years           10
# 24951  Switzerland  2013  female  15-24 years           17
# 24963  Switzerland  2014  female  15-24 years           14

# %%
F_DF.sum().suicides_no
# Out:
# 71

# %% [markdown]
# ## Create data frame using pd.DataFrame

# %%
import pandas as pd

# %% [markdown]
# ## when data is arrange in column

# %%
names = ['vishal','mohit','karan','ravi']
hobbies = ['cricket','footbal','basketball','coading']
height = ['172 cm','165 cm','173 cm','175 cm']

# %%
information = pd.DataFrame({'Names' : names, 'Hobbies' : hobbies, 'Height' : height})#dictionary

# %%
information
# Out:
#     Names     Hobbies  Height
# 0  vishal     cricket  172 cm
# 1   mohit     footbal  165 cm
# 2   karan  basketball  173 cm
# 3    ravi     coading  175 cm

# %%
information.set_index('Names', inplace=True)

# %%
information
# Out:
#            Hobbies  Height
# Names
# vishal     cricket  172 cm
# mohit      footbal  165 cm
# karan   basketball  173 cm
# ravi       coading  175 cm

# %% [markdown]
# ## When data is arrange in rows

# %%
row1 = ['vishal','cricket','172 cm']
row2 = ['mohit','footbal','165 cm']
row3 = ['karan','basketball','173 cm']
row4 = ['ravi','coading','175 cm']

# %%
info = pd.DataFrame(data = [row1, row2, row3, row4], columns = ['Names','Hobbies','Height'])

# %%
info
# Out:
#     Names     Hobbies  Height
# 0  vishal     cricket  172 cm
# 1   mohit     footbal  165 cm
# 2   karan  basketball  173 cm
# 3    ravi     coading  175 cm

# %%
info.set_index('Names', inplace=True)

# %%
info
# Out:
#            Hobbies  Height
# Names
# vishal     cricket  172 cm
# mohit      footbal  165 cm
# karan   basketball  173 cm
# ravi       coading  175 cm
